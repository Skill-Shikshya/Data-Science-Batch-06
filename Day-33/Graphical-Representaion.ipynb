# %%
# !pip install matplotlib

# %%
import pandas as pd

titanic_df = pd.read_csv("Titanic_data.csv")

# %% [markdown]
# ## 1. Bar Graph

# %%
titanic_df['Survived'].value_counts().plot(
    kind = 'bar', legend = True, figsize = (4,6),
    title = "Count of Survived Passengers", grid = True,
    fontsize = 10, colormap = "Dark2"
)
# Out:
# <Axes: title={'center': 'Count of Survived Passengers'}, xlabel='Survived'>

# %%
group_by_gender = titanic_df[['Sex','Survived']].groupby(by='Sex')
group_by_gender.value_counts().plot(kind = "bar", colormap = "Dark2")
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
import matplotlib.pyplot as plt

ax = titanic_df[['Embarked', 'Age']].groupby(by='Embarked').mean().plot(kind="bar")

# Set custom x-tick labels
ax.set_xticklabels(['Port A', 'Port B', 'Port C'], rotation=45)  # Adjust labels and rotation as needed

plt.show()

# %% [markdown]
# ## 2. Pie Chart

# %%
titanic_df[['Embarked', 'Age']].groupby(by='Embarked').mean().plot(
    kind="pie", subplots=True, colormap = "Pastel1"
)
# Out:
# array([<Axes: ylabel='Age'>], dtype=object)

# %%
titanic_df['Survived'].value_counts().plot(
    kind = 'pie', legend = True, figsize = (4,6),
    title = "Count of Survived Passengers", grid = True,
    fontsize = 10, colormap = "Dark2"
)
# Out:
# <Axes: title={'center': 'Count of Survived Passengers'}, ylabel='count'>

# %% [markdown]
# ## 3. Line Graph

# %%
titanic_df.loc[:10, "Fare"].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Scatter Plot (x,y)

# %%
titanic_df.plot.scatter("Age","Fare")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ## 5. Histogram

# %%
titanic_df.Age.plot.hist(bins=10, grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np

titanic_df.Age.plot.kde(ind = np.linspace(0,80,500))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## 8. Box Plot
#
# https://media.labxchange.org/xblocks/lb-LabXchange-d8863c77-html-1/211626365402575-b88c4d0fdacd5abb4c3dc2de3bc004bb.png

# %%
titanic_df.plot.box(column = "Age", by="Sex")
# Out:
# Age    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# ## 7. Heatmap

# %%
# !pip install seaborn

import seaborn as sns

# %%
correlation = titanic_df[["Pclass","Age","Fare","SibSp"]].corr()
correlation
# Out:
#           Pclass       Age      Fare     SibSp
# Pclass  1.000000 -0.369226 -0.549500  0.083081
# Age    -0.369226  1.000000  0.096067 -0.308247
# Fare   -0.549500  0.096067  1.000000  0.159651
# SibSp   0.083081 -0.308247  0.159651  1.000000

# %%
sns.heatmap(correlation, annot=True, cmap = "coolwarm")
# Out:
# <Axes: >
